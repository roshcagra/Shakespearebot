# %%
from __future__ import division, print_function
import numpy as np
import os
import sys
sys.path.append('../hw5/homework5_code')
from hmmlearn.hmm import MultinomialHMM

# %%
# %run 'preprocessing.ipynb'

# %%
quatrain_model = MultinomialHMM(n_components=20)
volta_model = MultinomialHMM(n_components=20)
couplet_model = MultinomialHMM(n_components=20)
quatrain_model.fit(np.concatenate(converted_quatrain_lines), quatrain_lengths)
volta_model.fit(np.concatenate(converted_volta_lines), volta_lengths)
couplet_model.fit(np.concatenate(converted_couplet_lines), couplet_lengths)
# Out:
# MultinomialHMM(algorithm='viterbi', init_params='ste', n_components=20,
#         n_iter=10, params='ste',
#         random_state=<mtrand.RandomState object at 0x1073cd5a0>,
#         startprob_prior=1.0, tol=0.01, transmat_prior=1.0, verbose=False)

# %%
def convert_sample(sample, words):
    ret = ''
    i = 0
    for word in np.nditer(sample[0]):
        curr_word = words[word]
        if i == 0 or len(curr_word) == 1:
            ret += curr_word.title() + ' '
        else:
            ret += curr_word + ' '
        i += 1
    return ret

def generate_naive_sonnet():
    sonnet = ''
    for _ in range(8):
        new_quatrain_line = quatrain_model.sample(avg_quatrain_length)
        sonnet += convert_sample(new_quatrain_line, quatrain_words) + '\n'
    for _ in range(4):
        new_volta_line = volta_model.sample(avg_volta_length)
        sonnet += convert_sample(new_volta_line, volta_words) + '\n'
    for _ in range(2):
        new_couplet_line = couplet_model.sample(avg_couplet_length)
        sonnet += convert_sample(new_couplet_line, couplet_words) + '\n'
    return sonnet
        
def generate_10_naive_sonnets():
    sonnets = ''
    for i in range(10):
        sonnets += str(i + 1) + '\n' + generate_naive_sonnet() + '\n'
    
    f = open("project2data/naive_shakespeare.txt","w")
    f.write(sonnets)
    return sonnets

# %%
print(generate_10_naive_sonnets())
# Out:
# 1
# Death'S filled what call fever of woe that
# Distilled shake love gift not slept brass put
# Who have that fresh thee thy to upon
# So thee all of tell the with than
# Consum'St seek self I join mine in I
# His the head is sweet feathered have tongue's
# Under a conquered the a with fair muse
# Tempteth youth made days far deep art then
# Your love common to inward muse base kind
# Me beauty in all doth masked stained chase
# Let time's survey do looks well my to
# He untainted this so suppose thoughts find how
# You and by love too my more that
# That that diest hell in replete these thou
#
# 2
# Then posterity is of my that fight extern
# Thy the heart yet keep embassy wide blamed
# Herein alone time for red book thee cars
# Against pierced if every wealth my thou pleasure
# Ah not top come wide my I didst
# That hours maladies age leaves on me slander's
# In the so face argument your delivers no
# Then disgrace tell feast forgoing that catch or
# O by deathbed you and selflove as afar
# Flatter take of this thee for he it
# But so and is affairs art now youth
# Born contracted so shouldst find waste yet that
# Feeds if me which love's and I spites
# My on their alone privilege sweet their grace
#
# 3
# But prime prove stand the out having they
# Incertainties hang parts constancy on it perceive thy
# Who from care land what not plagues that
# That did what gaze hated the shape her
# Thine where love thievish but mother with of
# Outlive so needy sweets I the good muse
# His of the my with heaven's the confound
# To hid store eyes the loan makeless hot
# No mad me wherefore which worthless alloblivious mightst
# Not by receive rose to world mad first
# Which be saw found make eye what world
# To and why I is his wear he
# And love who youth drawn nothing thou mine
# Let more again spent wilt slow the false
#
# 4
# Upon thy glory strangely and part I wilt
# O to in seen that unkindness you body
# Advantage from spirit leaves my not my the
# Of worth the that burn love seeing compounds
# But for tillage are all shows converted called
# No that other heaven's his truth lover appear
# I against dreaming having is hue the not
# Shalt is of I and I I me
# So be upon bear me down ages answers
# O that by is read be accumulate then
# Meditation thine see wondrous still hand 'gainst night
# But it dial in created woe glass contrary
# On suspect my like thy new art nights
# If answer twice so beauty's hold do he
#
# 5
# Calls that subsist objects and earth pay me
# Great your thy and vulgar world see debarred
# Counting thrust thunder thou which after brass true
# Love before and be thy long those true
# For to sigh decrease acquaintance self thou to
# Ah the disabled effectually overplus in answer more
# In in our when better to not thee
# With see to that says is not to
# And far prophecies those and thy thou a
# Then for gifts spite sick living best leases
# So the stay they feeble this of they
# Yet a think from upon copy thrive I
# To and general of beauty for drawn thy
# I remembered life thou would then he slight
#
# 6
# The desert thou mind what muse lies this
# Dost still thriftless blame as for see time
# Not of hymn mine with thee I is
# And proudly and seen kind now the own
# Even where what smell with crowned delight her
# Excusing is art pen thoughts taker than his
# Wishing general yet in thy hath love far
# Tomorrow part dumb such ruining found writ it
# And retention suit in evil gain may composition
# But so fair roses than of not unrest
# And it that she time's eyes room the
# It let than the love's still should thee
# Even of yore good that mayst to wake
# Then thine with most contains to brave with
#
# 7
# Gardens temptation I gentle patent sweets which ere
# Thy most so self possessed made bow name
# By rotten hear they fair so that in
# But fair minds in the on strive faith
# From the consecrate to wills fear entombed of
# The removed pride of who will see not
# Thou beauty's shore my have that quite my
# Love my to think dear with most thine
# Who become rage the can thee what me
# O away men best by say brow retention
# For monument of I common I critic kindness
# When his that one write not love's sick
# And my do pleasure seeming is need praise
# Ere lives days he and general thine despite
#
# 8
# And your doing the the sunken excess you
# And fears thee as owner's former odour the
# His thou where there and receives to for
# Why dear cheek brand half gentle breeds sicken
# That grecian yet blamed to before keep face
# Whose abuse full painting new I of fingers
# Being away sight the sick on physic doth
# Who thy make fitted taught purpose own winged
# Who delight and not here time's my adder's
# Though imprisoned to love's be afar a lines
# And forsake his is time hours attend of
# And debtor than love's first constancy and the
# That say dear being profit can had this
# There pain blessedfair all find wealth can rich
#
# 9
# Music mine invention my time gone razed in
# Dost is which than that then night to
# In so wailing spirit the a one thy
# When gentle the under the or with of
# And april than in bold as soul age
# That thy to sweet me rearward potions excel
# Farewell all i'll offend unless the not hath
# No that state basest show every thy west
# Then end is thy heaven's by buried thou
# Against made but love move being seem swartcomplexioned
# And with so up ever defeat thy discased
# Be the wilt palate mixed it daily that
# Then they thou wretched I part my much
# That thou sad so who love to writ
#
# 10
# When was which do might as character thee
# Yet in to given to with not to
# That war say young eye food out as
# Reason use depart beguiled the not self me
# Wound april so my the separation as write
# How abuse wooed thing love character lasting lies
# The less fresh fury to increase I skill
# Stealing translated love marriage tyrant gave stay true
# The thee when but from my oaths incertainty
# If in of desire come here my might
# Beauty deep what so charter looking best tribes
# Which bewailed will prove with the lies life
# Thou which blood feil ignorance most have muse
# To and must blood tears is on days
